# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
# cargamos el conjunto de datos
dataframe = read_csv('base_datos_ventas2.csv', sep=';')
dataset = dataframe.columns

# %%
def graficaAtributo(atributo,nombreLeyenda,titulo,xetiqueta,yetiqueta,nombreArchivo,alt=6,ancho=16):
    figure(figsize=(ancho,alt))
    dataframe['mes de analisis'] = dataframe['mes de analisis'].astype(str)
    dataframe['Año'] = dataframe['Año'].astype(str)
    plt.plot(dataframe['mes de analisis']+'-'+dataframe['Año'], dataframe[atributo], "-o")
    plt.legend([nombreLeyenda], loc = 'upper right')
    plt.grid(True)
    plt.title(titulo, fontsize = 15)
    plt.xlabel(xetiqueta, fontsize = 10)
    plt.ylabel(yetiqueta, fontsize = 10)
    plt.xticks(fontsize=7, color = 'g', rotation = 90) 
    #plt.savefig(nombreArchivo, dpi=300)
#Grafica del atributo a predecir
graficaAtributo('CANTIDAD_CLASIF_A','Ventas',"Ventas 2012-2018","Tiempo (Mes&Año)","Ventas",'ventasGrafica.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('ventas_totales_Veh_livianos','Ventas Veh Liv',"Ventas Veh Liv 2012-2018","Tiempo (Mes&Año)","Ventas",'ventas_totales_Veh_livianos.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('Tasa de inflación (mensual)','Tasa de inflación (mensual)',"Tasa de inflación (mensual) 2012-2018","Tiempo (Mes&Año)","T. Inflacion",'t_inflacion.png',10,16)

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('Población Económicamente Activa (Nacional)','Población Económicamente Activa (Nacional)',"Población Económicamente Activa (Nacional)","Tiempo (Mes&Año)","P. Activa",'p_activa.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('Exportaciones totales (USD)','Exportaciones totales (USD)',"Exportaciones totales (USD)","Tiempo (Mes&Año)","Exp. Totales",'exp_totales.png',16,16)

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('PRODUCTO INTERNO BRUTO (PIB) TRIMESTRAL (MILES DE DOL)','PRODUCTO INTERNO BRUTO (PIB) TRIMESTRAL (MILES DE DOL)',"PRODUCTO INTERNO BRUTO (PIB) TRIMESTRAL (MILES DE DOL)","Tiempo (Mes&Año)","PIB Trimestral",'pib_trim.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('Balanza comercial total (millones de usd)','Balanza comercial total (millones de usd)',"Balanza comercial total (millones de usd)","Tiempo (Mes&Año)","Balanza Comercial",'b_comercial.png',16,16)

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo(' Valor Unitario del petroleo Promedio (eje der.) ',' Valor Unitario del petroleo Promedio (eje der.) '," Valor Unitario del petroleo Promedio (eje der.) 2012-2018","Tiempo (Mes&Año)","Valor Unit. Petroleo",'v_unitario_petroleo.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('EXPORTACIONES PETROLERAS (miles de USD) FOB (der)','EXPORTACIONES PETROLERAS (miles de USD) FOB (der)',"EXPORTACIONES PETROLERAS (miles de USD) FOB (der) 2012-2018","Tiempo (Mes&Año)","Exportaciones Petroleras",'exp_petroleo.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('Import. CIF MILLONES USD','Import. CIF MILLONES USD',"Import. CIF MILLONES USD 2012-2018","Tiempo (Mes&Año)","Importaciones CIF",'imp_cif.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('Exp. no petroleras MILLONES USD','Exp. no petroleras MILLONES USD',"Exp. no petroleras MILLONES USD 2012-2018","Tiempo (Mes&Año)","Exp. no petroleras MILLONES USD",'exp_no_petroleras.png',16,16)

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('IMPORTACIONES Petroleras','IMPORTACIONES Petroleras',"IMPORTACIONES Petroleras 2012-2018","Tiempo (Mes&Año)","Importaciones Petroleras",'imp_petroleo.png')

# %%
#Grafica de Venta de Vehiculos livianos
graficaAtributo('IMPORTACIONES No Petroleras','IMPORTACIONES No Petroleras',"IMPORTACIONES No Petroleras 2012-2018","Tiempo (Mes&Año)","IMPORTACIONES No Petroleras",'imp_no_petroleo.png')
